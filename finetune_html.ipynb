# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://aws.amazon.com/blogs/machine-learning/an-introduction-to-preparing-your-own-dataset-for-llm-training/

# %%
from trafilatura import fetch_url, extract, html2txt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from trafilatura import fetch_url, extract, html2txt
#
# ModuleNotFoundError: No module named 'trafilatura'
